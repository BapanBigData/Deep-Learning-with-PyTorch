# %%
from utils import load_results_from_json, plot_training_history

# %%
results = load_results_from_json(
    filepath='training_artifact/training_results.json'
)

# %%
plot_training_history(
    epochs=len(results['epochs']),
    train_losses=results['train_loss'],
    train_accuracies=results['train_acc'],
    test_losses=results['test_loss'],
    test_accuracies=results['test_acc']
)
